# %% [markdown]
# # Capstone: Text Factorizing with NLP
# ## Thomas Ludlow

# %% [markdown]
# # 06 - Model Interface

# %% [markdown]
# This notebook contains the functions to process text input to match model training EDA steps.  This interface will be used to optimize the LDA and FFRNN models.

# %% [markdown]
# **Libraries**

# %%
# Python Data Science
import re
import time
import numpy as np
import pandas as pd

# Natural Language Processing
import spacy
import gensim
import pyLDAvis.gensim
from gensim.corpora import Dictionary
from gensim.models import TfidfModel, ldamodel, ldamulticore, CoherenceModel
from nltk.stem import PorterStemmer

# Modeling Prep
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.externals import joblib

# Neural Net
import keras
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Dropout
from keras.callbacks import EarlyStopping

# Plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Override deprecation warnings
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

# %% [markdown]
# **Preprocessing Function**

# %%
def preprocess(text_list, sw=['the','a','but','like','for'], to_stem=False):
    # Import spaCy "English Medium" library, which does not include vectors
    nlp = spacy.load('en_core_web_md')
    
    # Run spaCy process on each paragraph and store docs in list
    pars_nlp = []
    for par in text_list:
        pars_nlp.append(nlp(par))
    
    # Store lemma from spaCy docs
    pars_lemma = []
    for par_nlp in pars_nlp:
        pars_lemma.append([token.lemma_ for token in par_nlp     # List comprehension
                           if token.lemma_ != '-PRON-'           # Pronouns are excluded
                           and token.pos_ != 'PUNCT'             # Punctionation is excluded
                           and token.is_alpha                    # Numbers are excluded
                           and not token.is_stop])               # Stop words are excluded
        
    # Stem lemma with NLTK PorterStemmer and remove stop words
    if to_stem: ps = PorterStemmer()
    pars_lemma_sw = []
    for vec_list in pars_lemma:    
        update_list = []
        for token in vec_list:
            if token in sw: continue
            if to_stem: update_list.append(ps.stem(token))
            else: update_list.append(token)
        pars_lemma_sw.append(update_list)
        
    return pars_lemma_sw

# %% [markdown]
# **Load Bumper Stickers from Text Data**

# %%
text_data = pd.read_csv('./data/text_data.csv')
text_data.head()
# Out:
#                                   Title                      Author  \
# 0  Book of the Dead: The Papyrus of Ani                         Ani
# 1                        The Categories                   Aristotle
# 2                           The Poetics                   Aristotle
# 3                            The Gospel  Buddha, Siddhartha Guatama
# 4                              The Word  Buddha, Siddhartha Guatama
#
#                    Filename  \
# 0           ani_papyrus.txt
# 1  aristotle_categories.txt
# 2     aristotle_poetics.txt
# 3         buddha_gospel.txt
# 4           buddha_word.txt
#
#                                            Start Key  \
# 0                                 THE PAPYRUS OF ANI
# 1  *** START OF THIS PROJECT GUTENBERG EBOOK THE ...
# 2                     ARISTOTLE ON THE ART OF POETRY
# 3                                             500 BC
# 4                                   BUDDHA, THE WORD
#
#                                              End Key  \
# 0                                          ***END***
# 1  End of the Project Gutenberg EBook of The Cate...
# 2  End of the Project Gutenberg EBook of The Poet...
# 3                                          ***END***
# 4                                            THE END
#
#                        Category  \
# 0                    Polytheism
# 1                  Hylomorphism
# 2  Dramatic and Literary Theory
# 3                      Buddhism
# 4                      Buddhism
#
#                                       Bumper Sticker Original Language  \
# 0  Magic spells will assist the dead in journey t...      Heiroglyphic
# 1             Being is a compound of matter and form             Greek
# 2  Dramatic works imitate but vary in music, char...             Greek
# 3  Human suffering and the cycle of death and reb...           English
# 4  Four noble truths are understood by the enligh...           English
#
#   Country          Year  Year Val  \
# 0   Egypt  2400-1250 BC     -1250
# 1  Greece       ~335 BC      -335
# 2  Greece        335 BC      -335
# 3   India       ~500 BC      -500
# 4   India       ~500 BC      -500
#
#                                            Wiki Link  \
# 0     https://en.wikipedia.org/wiki/Book_of_the_Dead
# 1  https://en.wikipedia.org/wiki/Categories_(Aris...
# 2  https://en.wikipedia.org/wiki/Poetics_(Aristotle)
# 3  https://en.wikipedia.org/wiki/The_Gospel_of_Bu...
# 4  https://en.wikipedia.org/wiki/Noble_Eightfold_...
#
#                                            Wiki Text
# 0  The Book of the Dead is an ancient Egyptian fu...
# 1  The Categories (Greek Κατηγορίαι Katēgoriai; L...
# 2  Aristotle's Poetics (Greek: Περὶ ποιητικῆς; La...
# 3  The Gospel of Buddha was an 1894 book by Paul ...
# 4  The Noble Eightfold Path (Pali: ariyo aṭṭhaṅgi...

# %% [markdown]
# **Define Stop Words**
#  - Roman Numerals
#  - Additional stop words

# %%
sw = ['i','ii','iii','iv','v','vi','vii','viii',
      'ix','x','xi','xii','xiii','xiv','xv','xvi',
      'xvii','xviii','xix','xx','xxi','xxii',
      'the','a','but','like','for']

# %% [markdown]
# **Preprocess Bumper Stickers**

# %%
bs_vecs = preprocess(text_data['Bumper Sticker'].tolist(), sw)

# %%
len(bs_vecs)
# Out:
# 45

# %%
bs_vecs[:5]
# Out:
# [['magic',
#   'spell',
#   'will',
#   'assist',
#   'dead',
#   'in',
#   'journey',
#   'through',
#   'underworld',
#   'and',
#   'into',
#   'afterlif'],
#  ['be', 'be', 'compound', 'of', 'matter', 'and', 'form'],
#  ['dramat',
#   'work',
#   'imit',
#   'vari',
#   'in',
#   'music',
#   'charact',
#   'good',
#   'and',
#   'narr',
#   'present'],
#  ['human',
#   'suffer',
#   'and',
#   'cycl',
#   'of',
#   'death',
#   'and',
#   'rebirth',
#   'can',
#   'be',
#   'overcom',
#   'with',
#   'nirvana',
#   'through',
#   'enlighten'],
#  ['four',
#   'nobl',
#   'truth',
#   'be',
#   'understand',
#   'by',
#   'enlighten',
#   'where',
#   'nirvana',
#   'can',
#   'be',
#   'achiev',
#   'through',
#   'follow',
#   'eightfold',
#   'path']]

# %% [markdown]
# ## Get LDA Topic Values for Input Text

# %% [markdown]
# **Load LDA Dictionary and Model**

# %%
g_dict = Dictionary.load('./models/g_dict')
lda_model = Dictionary.load('./models/lda_model')

# %% [markdown]
# **LDA Values Function**

# %%
def lda_values_df(pp_vectors, g_dict=g_dict, lda_model=lda_model):
    bow_vectors = []
    for vec in pp_vectors:
        bow_vectors.append(g_dict.doc2bow(vec))
        
    lda_values = []
    for bow in bow_vectors:
        lda_values.append(lda_model.get_document_topics(bow))
        
    lda_df = pd.DataFrame(columns=[n for n in range(lda_model.num_topics)])
    for i in range(len(lda_values)):
        for topic, proba in lda_values[i]:
            lda_df.loc[i, topic] = proba
    
    return lda_df

# %%
lda_df = lda_values_df(bs_vecs)

# %%
lda_df.head()
# Out:
#            0          1         2          3         4          5          6  \
# 0   0.076627   0.142051  0.156698    0.11229  0.221816   0.179438  0.0819595
# 1  0.0851372  0.0407786  0.300815  0.0784416  0.264091   0.102458  0.0439741
# 2   0.118225   0.070841  0.392167  0.0695351  0.142963  0.0896406  0.0442353
# 3   0.140233  0.0309666  0.111486    0.11209  0.374928   0.097772  0.0636337
# 4   0.173145  0.0319661  0.152119  0.0984919  0.394654  0.0510391  0.0314807
#
#            7
# 0  0.0291192
# 1   0.084305
# 2  0.0723928
# 3  0.0688906
# 4  0.0671046

# %% [markdown]
# ## Factorize Topic Values for Input Text

# %% [markdown]
# **Load Scaler and FFRNN**

# %%
ss = joblib.load('./models/ss_full')

# %%
model_full = load_model('./models/model_full')

# %% [markdown]
# **Factorizing Function**

# %%
def nlp_factorize(lda_df, model=model_full, ss=ss):
    lda_sc = ss.transform(lda_df.values)
    preds = model.predict_proba(lda_sc)
    return preds

# %%
preds = nlp_factorize(lda_df)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
len(preds[0])
# Out:
# 33

# %% [markdown]
# ## Function `display_nlp_factors`

# %%
def display_nlp_factors(preds, raw_text, doc_number=0, thresh=0.01, target_authors=None):
    print('-'*80)
    print('Doc #:', doc_number)
    if target_authors: print('Target Author:', target_authors[doc_number])
    print('Text:\n', raw_text[doc_number])
    print('\nPhilosophical Factors:\n')
    
    result_list = [(text_data.Author.unique()[i], preds[doc_number][i]) for i in range(len(text_data.Author.unique()))]
    result_list.sort(key=lambda tup: tup[1], reverse=True)
    
    for j in range(len(text_data.Author.unique())):
        n_sp = 35 - len(result_list[j][0])
        if result_list[j][1] >= thresh:
            print('\t{}{}{}'.format(result_list[j][0],str(' '*n_sp),str(round(result_list[j][1], 3))))
    print('-'*80)

# %%
for k in range(len(preds)):
    display_nlp_factors(preds, text_data['Bumper Sticker'].tolist(), doc_number=k, target_authors=text_data['Author'].tolist(), thresh=.05)
# Out:
# --------------------------------------------------------------------------------
# Doc #: 0
# Target Author: Ani
# Text:
#  Magic spells will assist the dead in journey through the underworld and into the afterlife
#
# Philosophical Factors:
#
# 	Muhammad                           0.265
# 	Nietzsche, Friedrich               0.238
# 	Moses                              0.181
# 	Matthew, Mark, Luke, John          0.15
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 1
# Target Author: Aristotle
# Text:
#  Being is a compound of matter and form
#
# Philosophical Factors:
#
# 	Plato                              0.37
# 	Nietzsche, Friedrich               0.127
# 	Sun Tzu                            0.096
# 	Hobbes, Thomas                     0.083
# 	Muhammad                           0.061
# 	Spinoza, Baruch                    0.057
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 2
# Target Author: Aristotle
# Text:
#  Dramatic works imitate but vary in music, character goodness, and narrative presentation
#
# Philosophical Factors:
#
# 	Plato                              0.515
# 	Keynes, John Maynard               0.09
# 	James, William                     0.074
# 	Mill, John Stuart                  0.063
# 	Sun Tzu                            0.059
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 3
# Target Author: Buddha, Siddhartha Guatama
# Text:
#  Human suffering and the cycle of death and rebirth can be overcome with Nirvana through enlightenment
#
# Philosophical Factors:
#
# 	Muhammad                           0.435
# 	Nietzsche, Friedrich               0.308
# 	Plato                              0.059
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 4
# Target Author: Buddha, Siddhartha Guatama
# Text:
#  Four noble truths are understood by the enlightened, where Nirvana can be achieved through following the eightfold path
#
# Philosophical Factors:
#
# 	Spinoza, Baruch                    0.358
# 	Lao Tzu                            0.193
# 	Nietzsche, Friedrich               0.128
# 	Plato                              0.07
# 	Muhammad                           0.065
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 5
# Target Author: Confucius
# Text:
#  Moral welfare and human virtue spring from altruism
#
# Philosophical Factors:
#
# 	Gibran, Khalil                     0.567
# 	Nietzsche, Friedrich               0.186
# 	Muhammad                           0.075
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 6
# Target Author: Confucius
# Text:
#  The superior man uses self-watchfulness, leniency and sincerity to direct the mind to a state of equilibrium
#
# Philosophical Factors:
#
# 	Plato                              0.344
# 	Nietzsche, Friedrich               0.137
# 	Hobbes, Thomas                     0.1
# 	Spinoza, Baruch                    0.064
# 	Muhammad                           0.061
# 	Sun Tzu                            0.058
# 	Lao Tzu                            0.057
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 7
# Target Author: Descartes, Rene
# Text:
#  Philosophy is the study of wisdom, and knowledge exists in varying degrees
#
# Philosophical Factors:
#
# 	Plato                              0.434
# 	Mill, John Stuart                  0.087
# 	Sun Tzu                            0.077
# 	Rousseau, Jean-Jacques             0.053
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 8
# Target Author: Dewey, John
# Text:
#  A successful scientific theory reveals known either true or false about nature's unobservable objects, properties, or processes
#
# Philosophical Factors:
#
# 	Spinoza, Baruch                    0.36
# 	Mill, John Stuart                  0.174
# 	James, William                     0.113
# 	Plato                              0.07
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 9
# Target Author: Gibran, Khalil
# Text:
#  The human condition is linked to union with the infinite
#
# Philosophical Factors:
#
# 	Nietzsche, Friedrich               0.296
# 	Plato                              0.228
# 	Spinoza, Baruch                    0.113
# 	Muhammad                           0.067
# 	Descartes, Rene                    0.063
# 	Sun Tzu                            0.052
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 10
# Target Author: Hayek, Friedrich
# Text:
#  Government control of economic decision-making inevitably results in tyranny
#
# Philosophical Factors:
#
# 	Smith, Adam                        0.32
# 	Paine, Thomas                      0.172
# 	Keynes, John Maynard               0.093
# 	Rousseau, Jean-Jacques             0.064
# 	Hayek, Friedrich                   0.06
# 	Mill, John Stuart                  0.051
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 11
# Target Author: Hobbes, Thomas
# Text:
#  Only strong unified government can save from "the war of all against all"
#
# Philosophical Factors:
#
# 	Nietzsche, Friedrich               0.366
# 	Muhammad                           0.118
# 	Rousseau, Jean-Jacques             0.104
# 	Paine, Thomas                      0.075
# 	Plato                              0.06
# 	Rand, Ayn                          0.054
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 12
# Target Author: Hume, David
# Text:
#  There is nothing but natural elements, principles, and relations
#
# Philosophical Factors:
#
# 	Plato                              0.513
# 	Spinoza, Baruch                    0.097
# 	Mill, John Stuart                  0.052
# 	Descartes, Rene                    0.051
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 13
# Target Author: James, William
# Text:
#  The practical effects of ideas are the whole of ideas
#
# Philosophical Factors:
#
# 	Spinoza, Baruch                    0.296
# 	Mill, John Stuart                  0.203
# 	Plato                              0.1
# 	Kant, Immanuel                     0.079
# 	Descartes, Rene                    0.068
# 	Russell, Bertrand                  0.063
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 14
# Target Author: Kant, Immanuel
# Text:
#  The basis of "a priori" knowledge is both analytic and synthetic
#
# Philosophical Factors:
#
# 	Plato                              0.364
# 	Spinoza, Baruch                    0.15
# 	Descartes, Rene                    0.111
# 	Mill, John Stuart                  0.074
# 	Locke, John                        0.059
# 	Russell, Bertrand                  0.053
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 15
# Target Author: Keynes, John Maynard
# Text:
#  Markets are naturally volatile, and governments should increase demand through spending to relieve unemployment
#
# Philosophical Factors:
#
# 	Plato                              0.323
# 	Nietzsche, Friedrich               0.167
# 	Sun Tzu                            0.105
# 	Muhammad                           0.098
# 	Spinoza, Baruch                    0.055
# 	Rand, Ayn                          0.054
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 16
# Target Author: Khyyam, Omar
# Text:
#  Philosophy fails to satisfy, so drink joyously from the cup of life
#
# Philosophical Factors:
#
# 	Nietzsche, Friedrich               0.457
# 	Plato                              0.101
# 	Khyyam, Omar                       0.068
# 	Paine, Thomas                      0.067
# 	Muhammad                           0.057
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 17
# Target Author: Lao Tzu
# Text:
#  Living in harmony with "the way"
#
# Philosophical Factors:
#
# 	Gibran, Khalil                     0.439
# 	Plato                              0.219
# 	Nietzsche, Friedrich               0.107
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 18
# Target Author: Locke, John
# Text:
#  The problem of religion overtaking government can be addressed with religious toleration
#
# Philosophical Factors:
#
# 	Muhammad                           0.242
# 	Plato                              0.232
# 	Nietzsche, Friedrich               0.221
# 	Sun Tzu                            0.112
# 	Hobbes, Thomas                     0.073
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 19
# Target Author: Locke, John
# Text:
#  All knowledge comes from and is limited by experience, and the mind starts as a blank slate
#
# Philosophical Factors:
#
# 	Plato                              0.345
# 	Nietzsche, Friedrich               0.134
# 	Spinoza, Baruch                    0.108
# 	Sun Tzu                            0.071
# 	Muhammad                           0.051
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 20
# Target Author: Machiavelli, Nicolo
# Text:
#  Political power by any means necessary
#
# Philosophical Factors:
#
# 	Paine, Thomas                      0.209
# 	Plato                              0.174
# 	Keynes, John Maynard               0.147
# 	Sun Tzu                            0.069
# 	Smith, Adam                        0.064
# 	Mill, John Stuart                  0.06
# 	Nietzsche, Friedrich               0.055
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 21
# Target Author: Marx, Karl and Friedrich Engels
# Text:
#  Common ownership of means of production with no classes, no state
#
# Philosophical Factors:
#
# 	Mill, John Stuart                  0.192
# 	Rousseau, Jean-Jacques             0.142
# 	Paine, Thomas                      0.082
# 	Keynes, John Maynard               0.079
# 	Smith, Adam                        0.079
# 	Plato                              0.065
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 22
# Target Author: Matthew, Mark, Luke, John
# Text:
#  God sacrificed his son Jesus to save man from eternal damnation
#
# Philosophical Factors:
#
# 	Nietzsche, Friedrich               0.44
# 	Muhammad                           0.145
# 	Plato                              0.069
# 	Gibran, Khalil                     0.055
# 	Sun Tzu                            0.053
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 23
# Target Author: Mill, John Stuart
# Text:
#  System of logic using empiricist principles
#
# Philosophical Factors:
#
# 	Plato                              0.356
# 	Mill, John Stuart                  0.103
# 	Keynes, John Maynard               0.081
# 	Rousseau, Jean-Jacques             0.078
# 	Paine, Thomas                      0.069
# 	Sun Tzu                            0.069
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 24
# Target Author: Mill, John Stuart
# Text:
#  Individual liberty from "tyranny of majority"
#
# Philosophical Factors:
#
# 	Keynes, John Maynard               0.173
# 	Mill, John Stuart                  0.165
# 	Marx, Karl and Friedrich Engels    0.139
# 	Smith, Adam                        0.073
# 	Paine, Thomas                      0.069
# 	Hayek, Friedrich                   0.061
# 	Hume, David                        0.061
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 25
# Target Author: Mill, John Stuart
# Text:
#  The best actions are those that create the greatest well-being
#
# Philosophical Factors:
#
# 	Muhammad                           0.329
# 	Nietzsche, Friedrich               0.309
# 	Plato                              0.148
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 26
# Target Author: Moses
# Text:
#  Loyalty to God the creator begets tranquility
#
# Philosophical Factors:
#
# 	Gibran, Khalil                     0.487
# 	Nietzsche, Friedrich               0.136
# 	Muhammad                           0.13
# 	Matthew, Mark, Luke, John          0.067
# 	Plato                              0.055
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 27
# Target Author: Muhammad
# Text:
#  There is one God, Allah, and Muhammad is his prophet
#
# Philosophical Factors:
#
# 	Matthew, Mark, Luke, John          0.316
# 	Nietzsche, Friedrich               0.199
# 	Gibran, Khalil                     0.172
# 	Muhammad                           0.116
# 	Moses                              0.099
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 28
# Target Author: Nietzsche, Friedrich
# Text:
#  All ideations take place from particular perspectives
#
# Philosophical Factors:
#
# 	Plato                              0.628
# 	Nietzsche, Friedrich               0.065
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 29
# Target Author: Paine, Thomas
# Text:
#  American colonists should revolt against inevitable British oppression in pursuit of egalitarian government
#
# Philosophical Factors:
#
# 	Smith, Adam                        0.327
# 	Marx, Karl and Friedrich Engels    0.197
# 	Paine, Thomas                      0.144
# 	Hayek, Friedrich                   0.12
# 	Keynes, John Maynard               0.111
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 30
# Target Author: Paine, Thomas
# Text:
#  Political revolution is permissible when a government does not safeguard the natural rights of its people
#
# Philosophical Factors:
#
# 	Paine, Thomas                      0.248
# 	Rousseau, Jean-Jacques             0.234
# 	Rand, Ayn                          0.112
# 	Thoreau, Henry David               0.061
# 	Nietzsche, Friedrich               0.057
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 31
# Target Author: Plato
# Text:
#  The just state is ruled by the philosopher-king, striving for the ideal forms
#
# Philosophical Factors:
#
# 	Plato                              0.459
# 	Sun Tzu                            0.089
# 	Mill, John Stuart                  0.08
# 	Keynes, John Maynard               0.072
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 32
# Target Author: Plato
# Text:
#  The physical world is not as real or true as eternal, absolute, unchangeable ideas
#
# Philosophical Factors:
#
# 	Spinoza, Baruch                    0.47
# 	Plato                              0.154
# 	Descartes, Rene                    0.1
# 	Locke, John                        0.089
# 	Mill, John Stuart                  0.069
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 33
# Target Author: Rand, Ayn
# Text:
#  Reality exists separately from consciousness, and only capitalism respects the individual's moral right to pursue self-fulfillment
#
# Philosophical Factors:
#
# 	Nietzsche, Friedrich               0.35
# 	Plato                              0.146
# 	Spinoza, Baruch                    0.131
# 	Muhammad                           0.126
# 	Sun Tzu                            0.056
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 34
# Target Author: Rousseau, Jean-Jacques
# Text:
#  The people are sovereign in forming a political community to address problems in a commercial society
#
# Philosophical Factors:
#
# 	Rousseau, Jean-Jacques             0.202
# 	Plato                              0.182
# 	Paine, Thomas                      0.151
# 	Sun Tzu                            0.119
# 	Hayek, Friedrich                   0.065
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 35
# Target Author: Russell, Bertrand
# Text:
#  Modern empiricism allows philosophical questions to have scientific answers
#
# Philosophical Factors:
#
# 	Plato                              0.509
# 	Sun Tzu                            0.103
# 	Nietzsche, Friedrich               0.066
# 	Hobbes, Thomas                     0.064
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 36
# Target Author: Smith, Adam
# Text:
#  Absent counter-productive commercial regulation, markets will automatically find efficiency through division of labor and accumulation of capital
#
# Philosophical Factors:
#
# 	Plato                              0.167
# 	Paine, Thomas                      0.155
# 	Sun Tzu                            0.129
# 	Rousseau, Jean-Jacques             0.127
# 	Keynes, John Maynard               0.059
# 	Nietzsche, Friedrich               0.058
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 37
# Target Author: Spinoza, Baruch
# Text:
#  Despite its positive morality, faith must be kept separate from philosophy
#
# Philosophical Factors:
#
# 	Mill, John Stuart                  0.27
# 	Rousseau, Jean-Jacques             0.16
# 	Spinoza, Baruch                    0.094
# 	Keynes, John Maynard               0.083
# 	Plato                              0.08
# 	Kant, Immanuel                     0.065
# 	Paine, Thomas                      0.053
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 38
# Target Author: Spinoza, Baruch
# Text:
#  Reason is the chief source and test of knowledge
#
# Philosophical Factors:
#
# 	Plato                              0.437
# 	Sun Tzu                            0.09
# 	Spinoza, Baruch                    0.086
# 	Nietzsche, Friedrich               0.066
# 	Descartes, Rene                    0.061
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 39
# Target Author: Sun Tzu
# Text:
#  All warfare is based on deception, and knowing oneself and the enemy leads to victory without jeopardy
#
# Philosophical Factors:
#
# 	Muhammad                           0.513
# 	Nietzsche, Friedrich               0.35
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 40
# Target Author: Thoreau, Henry David
# Text:
#  People and nature are inherently good, and people are at their best when self-reliant and independent
#
# Philosophical Factors:
#
# 	Muhammad                           0.29
# 	Confucius                          0.236
# 	Nietzsche, Friedrich               0.212
# 	Plato                              0.093
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 41
# Target Author: Vyasa, Veda
# Text:
#  Pursuit of four paths to spirituality through fulfillment of warrior duty to "selfless action"
#
# Philosophical Factors:
#
# 	Plato                              0.248
# 	Nietzsche, Friedrich               0.137
# 	Hobbes, Thomas                     0.13
# 	Sun Tzu                            0.062
# 	Paine, Thomas                      0.057
# 	Hume, David                        0.055
# 	Lao Tzu                            0.051
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 42
# Target Author: Descartes, Rene
# Text:
#  Man is a thinking being capable of understanding the mind clearly, but anything else is difficult to know
#
# Philosophical Factors:
#
# 	Plato                              0.427
# 	Nietzsche, Friedrich               0.128
# 	Descartes, Rene                    0.109
# 	Spinoza, Baruch                    0.101
# 	Hobbes, Thomas                     0.059
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 43
# Target Author: Thoreau, Henry David
# Text:
#  Individuals have a duty to forbid governments from overruling their consciences
#
# Philosophical Factors:
#
# 	Rousseau, Jean-Jacques             0.213
# 	Plato                              0.153
# 	Nietzsche, Friedrich               0.128
# 	Hume, David                        0.121
# 	Spinoza, Baruch                    0.064
# --------------------------------------------------------------------------------
# --------------------------------------------------------------------------------
# Doc #: 44
# Target Author: Thoreau, Henry David
# Text:
#  Live with principle and do not take advantage of others
#
# Philosophical Factors:
#
# 	Plato                              0.455
# 	Nietzsche, Friedrich               0.112
# 	Sun Tzu                            0.101
# 	Muhammad                           0.069
# 	Confucius                          0.058
# --------------------------------------------------------------------------------
